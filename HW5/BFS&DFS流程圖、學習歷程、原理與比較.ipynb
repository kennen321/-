# %% [markdown]
# # 廣度優先搜尋法（Breadth-First Search）

# %% [markdown]
# 廣度優先搜尋演算法（英語：Breadth-First-Search，縮寫為BFS)，
#
# 又作寬度優先搜尋，或橫向優先搜尋，是一種圖形搜尋演算法。
#
# BFS是從根節點開始，沿著樹的寬度遍歷樹的節點。如果所有節點均被存取，則演算法中止。

# %% [markdown]
# ## BFS流程圖

# %%
from IPython.display import Image
Image("C:/Users/Administrator/Desktop/BFS流程.png")

# %% [markdown]
# 資料來源:http://alrightchiu.github.io/SecondRound/graph-breadth-first-searchbfsguang-du-you-xian-sou-xun.html
#       https://zh.wikipedia.org/wiki/%E5%B9%BF%E5%BA%A6%E4%BC%98%E5%85%88%E6%90%9C%E7%B4%A2

# %% [markdown]
# ## 手繪BFS流程圖

# %%
from IPython.display import Image
Image("C:/Users/Administrator/Desktop/BFS流程圖.png")

# %% [markdown]
# 題目來源:https://docs.google.com/presentation/d/e/2PACX-1vSYJYXUXvGAeTZ5fknxj_-EPm3zxgy4ITdImrXzy63Y-iZgs8uwVNmOaZlnx9fUNzsbo8kphvMTa0c4/pub?start=false&loop=false&delayms=3000&slide=id.g7a5d8b85ee_0_44

# %% [markdown]
# # 深度優先搜尋(Depth-First Search)

# %% [markdown]
# 深度優先搜尋演算法（Depth First Search，DFS）是一種用於遍歷或搜尋樹或圖的演算法。
# 沿著樹的深度遍歷樹的節點，儘可能深的搜尋樹的分支。當節點v的所在邊都己被探尋過，
# 搜尋將回溯到發現節點v的那條邊的起始節點。這一過程一直進行到已發現從源節點可達的所有節點為止。
# 如果還存在未被發現的節點，則選擇其中一個作為源節點並重複以上過程，
# 整個行程反覆進行直到所有節點都被存取為止。屬於盲目搜尋。

# %% [markdown]
# ##  DFS流程圖

# %%
from IPython.display import Image
Image("C:/Users/Administrator/Desktop/DFS流程.png")

# %% [markdown]
# 資料來源:http://alrightchiu.github.io/SecondRound/graph-depth-first-searchdfsshen-du-you-xian-sou-xun.html
# https://zh.wikipedia.org/wiki/%E6%B7%B1%E5%BA%A6%E4%BC%98%E5%85%88%E6%90%9C%E7%B4%A2

# %% [markdown]
# ## 手繪DFS流程圖

# %%
from IPython.display import Image
Image("C:/Users/Administrator/Desktop/DFS流程圖.png")

# %% [markdown]
# 題目來源:https://docs.google.com/presentation/d/e/2PACX-1vTma_vOZyE70O23KWw4I4Y78aAaT5fJSTq7Mae912kCwka_u5ZMWPoo14D86-x-57kZPbb6hAGktSW4/pub?start=false&loop=false&delayms=3000&slide=id.g6c077ea6e5_0_0

# %% [markdown]
# # BFS與DFS之比較

# %% [markdown]
# 一.
# BFS使用queue存取
# DFS是使用stack(堆疊)

# %% [markdown]
# 二.
# BFS的時間複雜度為O(|V|+|E|)，其中|V|是節點的數目，而|E|是圖中邊的數目
#
# DFS時間複雜度為O(V+E)，查詢所有頂點的鄰接點所需時間為O(E)，訪問頂點的鄰接點所花時間為O（V)

# %% [markdown]
# 三.
# BFS會把狀態逐個加入佇列，因此通常需要與狀態數成正比的記憶體空間。
#
# 反之，DFS是與遞迴深度成正比的。一般與狀態數相比，遞迴深度並不會太大，所以DFS更加省記憶體
#
# DFS使用遞迴函式程式可以簡潔地進行書寫，並且狀態管理也很簡單，所以大多數情況還是用DFS來實現相關問題。
#
# 反之，在求最短路問題時使用BFS為好。

# %% [markdown]
# 四.
# BFS是一種先進先出的資料結構，對於每一個節點而言，每一次搜尋，都是優先這一個節點的子節點，
# 所以每一次加入等待序列之後，都要等到某一個節點的所有子節點都被訪問完畢， 才可以進行下一個節點的訪問，
# 這正好是，先進入等待序列 的節點，先出序列進行計算，而後進入的，則後出，所以使用佇列儲存。
#
# DFS是一種先進後出的資料結構，在DFS中，我們要對每一條路徑走到底，才可以回溯前驅節點，所以當節點加入等待序列之後，
# 都要先讓後加入的（也就是子節點中的某一個） 節點先進行運算， 以保證是一條路走到底，所以符合棧的設計。

# %% [markdown]
# # BFS DFS學習歷程

# %% [markdown]
# ## 程式碼範例

# %%
# Python3 Program to print BFS traversal 
# from a given source vertex. BFS(int s) 
# traverses vertices reachable from s. 
from collections import defaultdict 
  
# This class represents a directed graph 
# using adjacency list representation 
class Graph:
    # Constructor 
    def __init__(self): 
        # default dictionary to store graph 
        self.graph = defaultdict(list) 

    # function to add an edge to graph 
    def addEdge(self,u,v): 
        self.graph[u].append(v) 
  
    # Function to print a BFS of graph 
    def BFS(self, s): 
        """
        :type s: int
        :rtype: list
        """
    def DFS(self, s):
        """
        :type s: int
        :rtype: list
        """

# %% [markdown]
# 一開始有先去看了一下影片，回來再試著自己打打看
#
# 首先要先建兩個list 為queue，另一個用來放入結果。

# %%
from collections import defaultdict 

class Graph:
 def __init__(self): 
        self.graph = defaultdict(list)
        
 def addEdge(self,u,v): 
        self.graph[u].append(v)
          
 def BFS(self, s):
        if s in self.graph:
            queue=[]
            go=[]
            queue.append(s)
            go.append(s)
            while queue:
                path=queue.pop(0)                
                for i in self.graph[path]:
                  if i  in go:                     
                     return go
                  else:
                      queue.append(i)
                      go.append(i)
                      
            return go
        else:
            print("no way")

# %%
恩...，果不其然一定會有一些ERROR產生，再試著改一下看看

# %%
g = Graph()
g.addEdge(1,2)
g.addEdge(1,4)
g.addEdge(2,3)
g.addEdge(2,6)
g.addEdge(3,5)
g.addEdge(3,7)
g.addEdge(7,5)
g.addEdge(5,2)
g.addEdge(5,6)
g.addEdge(6,1)
g.addEdge(4,6)
print(g.BFS(7))
# Out:
# [7, 5, 2, 6, 3]

# %% [markdown]
# 這邊重新修改過後看看

# %%
from collections import defaultdict 

class Graph:
 def __init__(self): 
        self.graph = defaultdict(list)
        
 def addEdge(self,u,v): 
        self.graph[u].append(v)
          
 def BFS(self, s):
        if s in self.graph:
            queue=[]
            go=[]
            queue.append(s)
            go.append(s)
            while queue:
                path=queue.pop(0)                
                for i in self.graph[path]:
                  if i  not in go:                     
                      queue.append(i)
                      go.append(i)
                      
            return go
        else:
            print("no way")

# %%
g = Graph()
g.addEdge(1,2)
g.addEdge(1,4)
g.addEdge(2,3)
g.addEdge(2,6)
g.addEdge(3,5)
g.addEdge(3,7)
g.addEdge(7,5)
g.addEdge(5,2)
g.addEdge(5,6)
g.addEdge(6,1)
g.addEdge(4,6)
print(g.BFS(7))
# Out:
# [7, 5, 2, 6, 3, 1, 4]

# %% [markdown]
# 這邊好像就可以了

# %% [markdown]
# 接下來按照一樣的邏輯來打DFS，只是換成STACK

# %%
from collections import defaultdict 

class Graph:
 def __init__(self): 
        self.graph = defaultdict(list)
        
 def addEdge(self,u,v): 
        self.graph[u].append(v)
          
def DFS(self, s):
        if s in self.graph:
            stack=[]
            go=[]
            stack.append(s)
            go.append(s)
            while stack:
                path=stack.pop(-1)                
                for i in self.graph[path]:
                  if i  in go:                     
                     return go
                  else:
                      stack.append(i)
                      go.append(i)
                      
            return go
        else:
            print("no way")

# %% [markdown]
# 這邊好像就錯比較大了，重新看了一下

# %%
from collections import defaultdict 

class Graph:
 def __init__(self): 
        self.graph = defaultdict(list)
        
 def addEdge(self,u,v): 
        self.graph[u].append(v) 
 def DFS(self, s):
   if s in self.graph:
     stack=[]
     go=[]
     stack.append(s)
     while stack:
         path=stack.pop(-1)
         go.append(path)
         for i in self.graph[path]:
             if i not in go:
                 stack.append(i)          
     return go
   else:
       print("no way")

# %%
g = Graph()
g.addEdge(0, 1)
g.addEdge(0, 2)
g.addEdge(1, 2)
g.addEdge(2, 0)
g.addEdge(2, 3)
g.addEdge(3, 3)
print(g.DFS(2))
# Out:
# [2, 3, 0, 1]

# %% [markdown]
# 這樣就完成了

# %% [markdown]
# 參考資料:https://www.youtube.com/watch?v=bD8RT0ub--0
#
#         https://codertw.com/%E7%A8%8B%E5%BC%8F%E8%AA%9E%E8%A8%80/102866/#outline__1_1_1
#
#         https://www.itread01.com/content/1541297601.html
#
#         https://codertw.com/%E7%A8%8B%E5%BC%8F%E8%AA%9E%E8%A8%80/102866/#outline__1
#
#         https://super9.space/archives/1562
#
#         https://www.geeksforgeeks.org/breadth-first-search-or-bfs-for-a-graph/
