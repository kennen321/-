# %% [markdown]
# ● 這是我做heap和merge比較的參考資料
#
# ● https://tingtseng.pixnet.net/blog/post/39924871-algorithm-time-complexity-%E6%BC%94%E7%AE%97%E6%B3%95%E6%99%82%E9%96%93%E8%A4%87%E9%9B%9C%E5%BA%A6%E6%95%B4%E7%90%86

# %%
from IPython.display import Image
Image("C:/Users/Administrator/Desktop/Heap sort&Merge sort比較.png")
